# %% [markdown]
# # Heppy Reihania Kartika Sari - 192400019

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#memasukan data latih
analisis = pd.read_csv("DSC.csv")
analisis

#Prestasi Siswa = 1 == Ya 
#Prestasi Siswa = 2 == Tidak
#Prestasi Sekolah = 1 == Cukup
#Prestasi Sekolah = 2 == Baik
# Out:
#              Jurusan  Matematika  Bahasa Inggris  Bahasa Indonesia  \
# 0         Matematika          92              86                88
# 1         Matematika          90              86                85
# 2     Sastra Inggris          82              87                92
# 3         Matematika          93              82                85
# 4     Sastra Inggris          86              85                88
# 5         Matematika          91              83                84
# 6   Sastra Indonesia          88              80                90
# 7   Sastra Indonesia          84              82                88
# 8     Sastra Inggris          79              89                85
# 9     Sastra Inggris          83              88                81
# 10    Sastra Inggris          82              85                84
# 11        Matematika          79              83                82
# 12        Matematika          82              85                83
# 13  Sastra Indonesia          88              85                92
# 14    Sastra Inggris          84              82                94
# 15    Sastra Inggris          92              90                82
# 16    Sastra Inggris          83              85                85
# 17  Sastra Indonesia          88              84                90
# 18        Matematika          93              82                88
# 19  Sastra Indonesia          88              80                95
# 20  Sastra Indonesia          84              82                92
#
#     Prestasi Siswa  Prestasi Sekolah
# 0                1                 1
# 1                1                 2
# 2                2                 1
# 3                1                 1
# 4                1                 1
# 5                2                 2
# 6                2                 1
# 7                1                 1
# 8                1                 1
# 9                2                 2
# 10               2                 1
# 11               2                 2
# 12               1                 2
# 13               1                 1
# 14               2                 1
# 15               1                 2
# 16               2                 2
# 17               2                 1
# 18               1                 1
# 19               2                 1
# 20               2                 1

# %%
analisis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Jurusan           21 non-null     object
#  1   Matematika        21 non-null     int64
#  2   Bahasa Inggris    21 non-null     int64
#  3   Bahasa Indonesia  21 non-null     int64
#  4   Prestasi Siswa    21 non-null     int64
#  5   Prestasi Sekolah  21 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 1.1+ KB

# %%
from sklearn.cluster import KMeans
#Memvisualkan persebaran data
plt.scatter(analisis.Matematika, analisis.Jurusan, s = 75, c = "c", marker = "o", alpha = 0.5)
plt.show()

# %%
x = analisis.drop(["Jurusan"], axis=1)
x.head()
# Out:
#    Matematika  Bahasa Inggris  Bahasa Indonesia  Prestasi Siswa  \
# 0          92              86                88               1
# 1          90              86                85               1
# 2          82              87                92               2
# 3          93              82                85               1
# 4          86              85                88               1
#
#    Prestasi Sekolah
# 0                 1
# 1                 2
# 2                 1
# 3                 1
# 4                 1

# %%
y = analisis["Jurusan"]
y
# Out:
# 0           Matematika
# 1           Matematika
# 2       Sastra Inggris
# 3           Matematika
# 4       Sastra Inggris
# 5           Matematika
# 6     Sastra Indonesia
# 7     Sastra Indonesia
# 8       Sastra Inggris
# 9       Sastra Inggris
# 10      Sastra Inggris
# 11          Matematika
# 12          Matematika
# 13    Sastra Indonesia
# 14      Sastra Inggris
# 15      Sastra Inggris
# 16      Sastra Inggris
# 17    Sastra Indonesia
# 18          Matematika
# 19    Sastra Indonesia
# 20    Sastra Indonesia
# Name: Jurusan, dtype: object

# %%
from sklearn.model_selection import train_test_split
# Import Gaussian Naive Bayes model
from sklearn.naive_bayes import GaussianNB
# Mengaktifkan/memanggil/membuat fungsi klasifikasi Naive bayes
modelnb = GaussianNB()
# Memasukkan data training pada fungsi klasifikasi naive bayes
nbtrain = modelnb.fit(x, y)
datauji = pd.read_csv("DSC.csv")
datauji.head()
# Out:
#           Jurusan  Matematika  Bahasa Inggris  Bahasa Indonesia  \
# 0      Matematika          92              86                88
# 1      Matematika          90              86                85
# 2  Sastra Inggris          82              87                92
# 3      Matematika          93              82                85
# 4  Sastra Inggris          86              85                88
#
#    Prestasi Siswa  Prestasi Sekolah
# 0               1                 1
# 1               1                 2
# 2               2                 1
# 3               1                 1
# 4               1                 1

# %%
x_test = datauji.drop(["Jurusan"], axis=1)
x_test.head(11)
# Out:
#     Matematika  Bahasa Inggris  Bahasa Indonesia  Prestasi Siswa  \
# 0           92              86                88               1
# 1           90              86                85               1
# 2           82              87                92               2
# 3           93              82                85               1
# 4           86              85                88               1
# 5           91              83                84               2
# 6           88              80                90               2
# 7           84              82                88               1
# 8           79              89                85               1
# 9           83              88                81               2
# 10          82              85                84               2
#
#     Prestasi Sekolah
# 0                  1
# 1                  2
# 2                  1
# 3                  1
# 4                  1
# 5                  2
# 6                  1
# 7                  1
# 8                  1
# 9                  2
# 10                 1

# %%
y_uji = datauji["Jurusan"]
y_uji.head(11)
# Out:
# 0           Matematika
# 1           Matematika
# 2       Sastra Inggris
# 3           Matematika
# 4       Sastra Inggris
# 5           Matematika
# 6     Sastra Indonesia
# 7     Sastra Indonesia
# 8       Sastra Inggris
# 9       Sastra Inggris
# 10      Sastra Inggris
# Name: Jurusan, dtype: object

# %%
Y_predict = nbtrain.predict(x_test)
print("Prediksi Naive Bayes : ",Y_predict)
# Out:
# Prediksi Naive Bayes :  ['Sastra Indonesia' 'Matematika' 'Sastra Indonesia' 'Sastra Indonesia'
#  'Sastra Indonesia' 'Matematika' 'Sastra Indonesia' 'Sastra Indonesia'
#  'Sastra Inggris' 'Sastra Inggris' 'Sastra Indonesia' 'Sastra Inggris'
#  'Matematika' 'Sastra Indonesia' 'Sastra Indonesia' 'Sastra Inggris'
#  'Sastra Inggris' 'Sastra Indonesia' 'Sastra Indonesia' 'Sastra Indonesia'
#  'Sastra Indonesia']

# %%
from sklearn.metrics import accuracy_score
accuracy= accuracy_score(y_uji, Y_predict)
print("Akurasi Naive Bayes : ",accuracy)
# Out:
# Akurasi Naive Bayes :  0.6190476190476191

# %%
# Menghitung nilai akurasi dari klasifikasi naive bayes 
from sklearn.metrics import classification_report
print(classification_report(y_uji, Y_predict))
# Out:
#                   precision    recall  f1-score   support
#
#       Matematika       1.00      0.43      0.60         7
# Sastra Indonesia       0.46      1.00      0.63         6
#   Sastra Inggris       0.80      0.50      0.62         8
#
#         accuracy                           0.62        21
#        macro avg       0.75      0.64      0.62        21
#     weighted avg       0.77      0.62      0.61        21
